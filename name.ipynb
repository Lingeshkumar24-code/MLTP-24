# %%
import pandas as pd
df = pd.read_csv("./namedataset.csv")

# %%
df.head()
# Out:
#    id   name   age    salary    joindate       city
# 0   1  Aarav  25.0   35000.0  2021-06-12  Bangalore
# 1   2   Diya  29.0   42000.0  2020-03-18    Chennai
# 2   3  Rohan  34.0   55000.0  2019-11-01  Hyderabad
# 3   4  Sneha  28.0   40000.0  2022-01-10       Pune
# 4   5  Karan  45.0  120000.0  2010-05-22     Mumbai

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        50 non-null     int64
#  1   name      50 non-null     object
#  2   age       47 non-null     float64
#  3   salary    49 non-null     float64
#  4   joindate  50 non-null     object
#  5   city      50 non-null     object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 2.5+ KB

# %%
df.describe()
# Out:
#              id        age         salary
# count  50.00000  47.000000      49.000000
# mean   25.50000  35.468085   63632.653061
# std    14.57738  13.443685   43759.138987
# min     1.00000  19.000000    5000.000000
# 25%    13.25000  27.000000   39000.000000
# 50%    25.50000  31.000000   50000.000000
# 75%    37.75000  40.500000   67000.000000
# max    50.00000  90.000000  220000.000000

# %%
df.isnull().sum()
# Out:
# id          0
# name        0
# age         3
# salary      1
# joindate    0
# city        0
# dtype: int64

# %%
df.isnull().sum().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['age'] = df['age'].fillna(df['age'].mean())

# %%
df['age'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['salary'] = df['salary'].fillna(df['salary'].median())

# %%
df['salary'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum().plot(kind='bar')
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#              id        age         salary
# count  50.00000  50.000000      50.000000
# mean   25.50000  35.468085   63360.000000
# std    14.57738  13.025644   43353.205281
# min     1.00000  19.000000    5000.000000
# 25%    13.25000  27.000000   39000.000000
# 50%    25.50000  32.500000   50000.000000
# 75%    37.75000  39.500000   66500.000000
# max    50.00000  90.000000  220000.000000

# %%
df.isnull().sum()
# Out:
# id          0
# name        0
# age         0
# salary      0
# joindate    0
# city        0
# dtype: int64

# %%
df['salary'] = pd.to_numeric(df['salary'], errors='coerce')
df['salary'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['salary'] = df['salary'].fillna(df['salary'].median())

# %%
df.isnull().sum()
# Out:
# id          0
# name        0
# age         0
# salary      0
# joindate    0
# city        0
# dtype: int64
